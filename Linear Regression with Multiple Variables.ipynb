# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("car data.csv")
df.head()
# Out:
#    speed  car_age  experience  risk
# 0    172       22    8.104042    42
# 1     94       17   11.429460    36
# 2    186       20   14.819477    45
# 3    151       10   15.343897    38
# 4    100        6   16.455807    47

# %%
df.isnull().sum()
# Out:
# speed         0
# car_age       0
# experience    2
# risk          0
# dtype: int64

# %%
mean_val = df.experience.mean()
mean_val
# Out:
# np.float64(10.13763041039928)

# %%
df.experience = df.experience.fillna(mean_val)
df.isnull().sum()
# Out:
# speed         0
# car_age       0
# experience    0
# risk          0
# dtype: int64
