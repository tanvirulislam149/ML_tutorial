# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('linear_data.csv')
df1.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
x_linear = df1[["x"]]
y_linear = df1[["y"]]

# %%
df2 = pd.read_csv('nonlinear_data.csv')
df2.head()
# Out:
#          x         y
# 0  0.00000 -0.155043
# 1  0.02004  0.081809
# 2  0.04008 -0.014298
# 3  0.06012  0.143978
# 4  0.08016  0.019553

# %%
x_nonlinear = df2[['x']]
y_nonlinear = df2[['y']]

# %% [markdown]
# # Visual Representation

# %%
#linear
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1) # Divides the figure into a grid: 1 → rows, 2 → columns, 1 → position (first plot)
plt.scatter(x_linear, y_linear, color='blue', label='Data with Linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Relationship')
plt.legend()

#non-linear
plt.subplot(1, 2, 2) # last 2 defines working on 2nd graph
plt.scatter(x_nonlinear, y_nonlinear, color='green', label='Data with Non-linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

plt.tight_layout()  # fix spacing
plt.show()  # show the final output

# %%
df1.corr() #linear
# Out:
#          x        y
# x  1.00000  0.99644
# y  0.99644  1.00000

# %%
df2.corr() #non linear
# Out:
#           x         y
# x  1.000000 -0.065736
# y -0.065736  1.000000

# %% [markdown]
# # Linear

# %%
from sklearn.linear_model import LinearRegression
reg1 = LinearRegression()

# %%
reg1.fit(x_linear, y_linear)
# Out:
# LinearRegression()

# %%
reg1.score(x_linear , y_linear)
# Out:
# 0.9928923730526016

# %%
plt.scatter(x_linear, y_linear, color='blue', label='Data with Linear Relationship')
plt.plot(x_linear, reg1.predict(x_linear), color='red', label='Best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Relationship')
plt.legend()

# %% [markdown]
# # Non-linear

# %%
reg2 = LinearRegression()
reg2.fit(x_nonlinear , y_nonlinear)
# Out:
# LinearRegression()

# %%
reg2.score(x_nonlinear , y_nonlinear)
# Out:
# 0.004321199719043656

# %%
plt.scatter(x_nonlinear, y_nonlinear, color='green', label='Data with Non-linear Relationship')
plt.plot(x_nonlinear, reg2.predict(x_nonlinear), color='red', label='Best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=6) # polynomial regression with degree 2 
X_poly = poly.fit_transform(x_nonlinear)

# %%
X_poly.shape  # makes 7 column for degree 6
# Out:
# (500, 7)

# %%
reg_poly = LinearRegression()

# %%
reg_poly.fit(X_poly, y_nonlinear)
# Out:
# LinearRegression()

# %%
reg_poly.score(X_poly, y_nonlinear)
# Out:
# 0.9930624844497349

# %%
plt.scatter(x_nonlinear, y_nonlinear, color='green', label='Data with Non-linear Relationship')
plt.plot(x_nonlinear, 2 * np.sin(x_nonlinear), color='orange', label='True Non-linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

# %% [markdown]
# # Seperate Train Test

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_poly,y_nonlinear, test_size=.30, random_state=1 )
